# %% [markdown]
# ## **POLLING LAYER IN CNN| MAXPOLLING IN CNN**

# %% [markdown]
# **The problem with convolution**
# - memory issue
# - translation varience(finding the features become location dependent even for the same image.)

# %% [markdown]
# #### **POLLING**
# - We add the polling layer after the convolution operation.
# - In the features map we obtain we do the relu operation.
# - After we obtain the non linear feature map, we use the pooling(which we have of different types.)

# %% [markdown]
# Consider a feature map
# $$
# \begin{bmatrix}
# 3&1&1&3\\
# 2&5&0&2\\
# 1&4&2&1\\
# 4&7&2&4
# \end{bmatrix}
# $$
# - to do the polling opeartion
#     - We provide size(to operate on window)(2x2)
#     - stride-2
#     - type-max
# - What we do i we pick a window of 2x2 and pick the max number
# - Then we move the window and select the window and again select the max
# - Thus obtain max matrix of above feature map is
# $$
#     \begin{bmatrix}
# 5&3\\
# 7&4
# \end{bmatrix}
# $$
# - Here we are selecting the most dominant feature in the receptive field
# - Here we are ignoring low level details

# %% [markdown]
# **Polling on volumes**
# - If we have multiple feature maps we do the polling on the individual features maps thus we get again the same number of the features maps.

# %%
import tensorflow
from tensorflow import keras 
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D
from keras import Sequential
from keras.datasets import mnist

# %%
(X_train,y_train),(X_test,y_test)=mnist.load_data()

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 11, 11, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 800)            │             0 │
# ...

# %% [markdown]
# **Advantages of Polling**
# _______________________________
# 1. Reduced size
# 2. Reduction in translation invarience.
# 3. No need of training parameters(which was need in convoltion for kernels)

# %% [markdown]
# **Types of Polling**
# - Maxpolling
# - Avgpolling(Take average of the polling area)
# - Global Polling
# -----------------------
# **Disadvantages of polling**'
# - loss of information
